# %%
from polyglot.text import Word

# %%
wordlist = ['hello', 'engaged', 'enraged', 'gloomy', 'paradoxical', 'fluffy', 'unloaded', 'pleased', 'implore', 'store', 'bloom', 'blossom', 'mountain', 'chivalrous', 'chritable', 'unexplored', 'authentication', 'boistrous', 'dogs', 'teeth', 'bleed', 'adversarial', 'aplomb', 'unkept', 'barrack', 'barricades', 'unpredictable', 'steed', 'brandished', 'wavering', 'unprecedented', 'exaggeration', 'hyperbole', 'distinct', 'lemmatization', 'stemming', 'horseshoe', 'breakfast', 'familiarity', 'legend', 'shared', 'commotion', 'contract', 'condominium', 'placement', 'legendary', 'unicorn', 'polarity', 'undertaker', 'parody', 'laughable', 'shopped', 'frustrate', 'debris', 'defiance', 'lonesome', 'dispute', 'reputation', 'maximum', 'minimum', 'destiny', 'destination', 'disdain', 'consideration', 'confluence', 'personality', 'Godhead', 'supremacy', 'inferiority', 'longing', 'proposturous', 'christmas', 'tidings', 'tide', 'untidy', 'bearer', 'bearable', 'suspension', 'elaborately', 'unethical', 'tooth', 'extravagant', 'tardiness', 'tidiness', 'expansion', 'dirty', 'hunger', 'uproot', 'bark', 'eloquent', 'hung', 'shapely', 'plump', 'flunked', 'homecoming', 'procrastination', 'proactive', 'networking', 'habitual', 'illumination', 'jargon', 'jostle', 'jutted', 'unapprehended', 'phantasma', 'phenomenon', 'elaborately', 'classified', 'justified', 'luminous', 'candella', 'candle', 'brightly', 'methodological', 'empirical', 'understanding', 'impressive', 'imprisoned', 'unholy', 'attitudes', 'wholesome', 'largely', 'dies', 'implies', 'flies', 'wives', 'thieves', 'ghastly', 'malicious', 'meticuluos', 'justify', 'funnier', 'functional', 'uploaded', 'distributed', 'happily', 'parallelized', 'untormented', 'qualified', 'mulititude', 'misgiving', 'startled', 'outliers', 'schooling', 'unsatisfied', 'joking', 'hooking', 'umbrella', 'planetary', 'outlandish', 'unfortunately', 'impress', 'dress', 'bless', 'fuss', 'abacus', 'bias', 'plankton', 'allothrophe', 'isomerism', 'condensation', 'resist', 'insist', 'pious', 'cross', 'expanding', 'primer', 'proton', 'nucleus', 'shell', 'evaluation', 'pristine', 'quell', 'quench', 'quill', 'thrill', 'drill', 'uphill', 'ominous', 'differentiation', 'guilty', 'boozing', 'rendezvous', 'unprecedented', 'recluse', 'replenish', 'reverberate', 'recognize', 'cognition', 'restituition', 'sabotage', 'sulking', 'humid', 'somber', 'subsidiary', 'transportation', 'translucent', 'vigilante', 'wealthy', 'zealous']
print len(wordlist)
# Out:
# 200

# %%
for word in wordlist:
    w = Word(word, language='en')
    print w, w.morphemes
# Out:
# hello ['hello']
# engaged ['engage', 'd']
# enraged ['en', 'raged']
# gloomy ['g', 'loom', 'y']
# paradoxical ['paradox', 'ical']
# fluffy ['flu', 'ff', 'y']
# unloaded ['un', 'load', 'ed']
# pleased ['pleas', 'ed']
# implore ['imp', 'lore']
# store ['store']
# bloom ['bloom']
# blossom ['blossom']
# mountain ['mountain']
# chivalrous ['ch', 'ival', 'rous']
# chritable ['ch', 'rit', 'able']
# unexplored ['un', 'explor', 'ed']
# authentication ['authentic', 'ation']
# boistrous ['bo', 'ist', 'rous']
# dogs ['dog', 's']
# teeth ['te', 'e', 'th']
# bleed ['ble', 'ed']
# adversarial ['advers', 'ar', 'ial']
# aplomb ['ap', 'lo', 'mb']
# unkept ['un', 'kept']
# barrack ['bar', 'rack']
# barricades ['barricade', 's']
# unpredictable ['un', 'predict', 'able']
# steed ['s', 'te', 'ed']
# brandished ['brand', 'ish', 'ed']
# wavering ['wave', 'ring']
# unprecedented ['un', 'precedent', 'ed']
# exaggeration ['exagge', 'ration']
# hyperbole ['hy', 'per', 'bo', 'le']
# distinct ['distinct']
# ...
